# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
#Se importa la tabla sucursal
data = pd.read_csv("1-week-individual-project/sucursal.csv")
data.head()
# Out:
#          id  comercioId  banderaId      banderaDescripcion  \
# 0     1-1-7           1          1              Super MAMI
# 1    10-1-1          10          1  Hipermercado Carrefour
# 2   10-1-10          10          1  Hipermercado Carrefour
# 3   10-1-11          10          1  Hipermercado Carrefour
# 4  10-1-112          10          1  Hipermercado Carrefour
#
#   comercioRazonSocial provincia            localidad  \
# 0     Dinosaurio S.A.      AR-X          SALSIPUEDES
# 1            INC S.A.      AR-B           San Isidro
# 2            INC S.A.      AR-B           Hurlingham
# 3            INC S.A.      AR-B  Malvinas Argentinas
# 4            INC S.A.      AR-A                Salta
#
#                    direccion        lat        lng       sucursalNombre  \
# 0              E53 1011 None -31.126667 -64.295250         Super Mami 4
# 1  Bernardo De Irigoyen 2647 -34.491345 -58.589025           San Isidro
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2333 entries, 0 to 2332
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2333 non-null   object
#  1   comercioId           2333 non-null   int64
#  2   banderaId            2333 non-null   int64
#  3   banderaDescripcion   2333 non-null   object
#  4   comercioRazonSocial  2333 non-null   object
#  5   provincia            2333 non-null   object
#  6   localidad            2333 non-null   object
#  7   direccion            2333 non-null   object
#  8   lat                  2333 non-null   float64
#  9   lng                  2333 non-null   float64
#  10  sucursalNombre       2333 non-null   object
#  11  sucursalTipo         2333 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 218.8+ KB

# %%
print(data.loc[1345])
# Out:
# id                                    15-1-450
# comercioId                                  15
# banderaId                                    1
# banderaDescripcion           Supermercados DIA
# comercioRazonSocial          DIA Argentina S.A
# provincia                                 AR-C
# localidad                      Capital Federal
# direccion              Av Gral. Las Heras 2421
# lat                                 -34.586393
# lng                                  -58.39829
# sucursalNombre                  450 - Recoleta
# sucursalTipo                      Autoservicio
# Name: 1345, dtype: object

# %%
#Se usa split para quitar los delimiter y posteriormente trabar con int para conectar los id de de sucursales entre tablas.
dataid=data['id'].str.split('-', expand=True)
dataid.head(50)
# Out:
#      0  1    2
# 0    1  1    7
# 1   10  1    1
# 2   10  1   10
# 3   10  1   11
# 4   10  1  112
# 5   10  1   12
# 6   10  1  123
# 7   10  1  128
# 8   10  1  136
# 9   10  1  139
# 10  10  1  142
# 11  10  1  147
# 12  10  1  149
# 13  10  1   15
# 14  10  1  156
# 15  10  1  157
# 16  10  1  159
# 17  10  1   16
# 18  10  1  161
# 19  10  1  162
# 20  10  1   17
# 21  10  1  171
# 22  10  1  175
# 23  10  1  178
# 24  10  1  179
# 25  10  1   18
# 26  10  1  180
# 27  10  1  183
# 28  10  1    2
# 29  10  1  204
# 30  10  1   21
# 31  10  1  210
# 32  10  1  214
# 33  10  1  217
# 34  10  1  219
# 35  10  1   22
# 36  10  1  220
# 37  10  1  227
# 38  10  1  229
# 39  10  1   23
# 40  10  1  231
# 41  10  1  232
# 42  10  1  233
# 43  10  1  234
# 44  10  1  235
# 45  10  1  239
# 46  10  1   24
# 47  10  1  240
# 48  10  1  241
# 49  10  1   25

# %%
#Seconvierte a str y se juntan las columnas
dataid2=dataid["all"]=dataid[0].astype(str)+dataid[1].astype(str)+dataid[2].astype(str)
dataid2
# Out:
# 0          117
# 1         1011
# 2        10110
# 3        10111
# 4       101112
#          ...
# 2328    935277
# 2329    935626
# 2330    935961
# 2331     93628
# 2332     93662
# Length: 2333, dtype: object

# %%
#Se crea la columna
data['IdSucursal']=dataid2

# %%
#Se genera la coneccion con el server de sql 
my_conn=create_engine("mysql+mysqldb://root:"miclave"@localhost/Workshop_1")

# %%
#Se prueba conexion ejecutando un comando de MySQL en python
r_set=my_conn.execute("SHOW TABLES");
for row in r_set:
    print(row)
# Out:
# ('sucursal',)
# ('Tipo',)

# %%
#Pasar el archivo a sql
data.to_sql(con=my_conn,name='Sucursal',if_exists='replace',index=False)
# Out:
# 2333

# %%
#Se importa primera tabla de precios
precios1 = pd.read_csv("/Users/Shared/CVS_Files/1-week-individual-project/precios_semana_20200413.csv",encoding="utf-16")
precios1.head(20)
# Out:
#     precio    producto_id sucursal_id
# 0    29.90  0000000001663     2-1-014
# 1    29.90  0000000002288     2-1-032
# 2    39.90  0000000002288     2-1-096
# 3   499.99  0000000205870     9-1-686
# 4   519.99  0000000205870     9-2-248
# 5   539.99  0000000205870      9-2-42
# 6   539.99  0000000205870     9-3-628
# 7   589.99  0000000205894     9-1-686
# 8   189.99  0000000205955     9-1-686
# 9   104.99  0000000205979     9-1-686
# 10  259.99  0000000206020     9-1-686
# 11  279.99  0000000206044     9-1-686
# 12  229.99  0000000206051     9-1-686
# 13  459.99  0000000206105     9-1-686
# 14  389.99  0000000206136     9-1-686
# 15  299.99  0000000206143     9-1-686
# 16  339.99  0000000206181     9-1-686
# 17  339.99  0000000206198     9-1-686
# 18  369.99  0000000206235     9-1-686
# 19  399.99  0000000206280     9-1-686

# %%
#Se importa la segunda tabla de precios
precios2=pd.read_json("/Users/Shared/CVS_Files/1-week-individual-project/precios_semana_20200503.json")
precios2.head(20)
# Out:
#     precio    producto_id sucursal_id
# 0     29.9  0000000002288     2-1-187
# 1     39.9  0000000002288     2-3-247
# 2   499.99  0000000205870     9-1-685
# 3   539.99  0000000205870      9-2-22
# 4   519.99  0000000205870      9-2-59
# 5   539.99  0000000205870     9-3-138
# 6   589.99  0000000205894     9-1-685
# 7   189.99  0000000205955     9-1-685
# 8   104.99  0000000205979     9-1-685
# 9      229  0000000206020     9-1-685
# 10  279.99  0000000206044     9-1-685
# 11  229.99  0000000206051     9-1-685
# 12  459.99  0000000206105     9-1-685
# 13  389.99  0000000206136     9-1-685
# 14  299.99  0000000206143     9-1-685
# 15  339.99  0000000206181     9-1-685
# 16  339.99  0000000206198     9-1-685
# 17  369.99  0000000206235     9-1-685
# 18  399.99  0000000206280     9-1-685
# 19  414.99  0000000206297     9-1-685

# %%
#Se importa la tercera tabla de precios
precios3=pd.read_excel("/Users/Shared/CVS_Files/1-week-individual-project/precios_semanas_20200419_20200426.xlsx")
precios3.head(20)
# Out:
#      precio sucursal_id  producto_id
# 0     399.0     2-1-092       2288.0
# 1     299.0     2-1-206       2288.0
# 2     399.0     2-2-241       2288.0
# 3   49999.0     9-1-430     205870.0
# 4   53999.0       9-2-4     205870.0
# 5   53999.0    9-3-5218     205870.0
# 6   58999.0     9-1-430     205894.0
# 7   18999.0     9-1-430     205955.0
# 8   10499.0     9-1-430     205979.0
# 9    2290.0     9-1-430     206020.0
# 10  27999.0     9-1-430     206044.0
# 11   2190.0     9-1-691     206044.0
# 12  22999.0     9-1-430     206051.0
# 13  45999.0     9-1-430     206105.0
# 14  38999.0     9-1-430     206136.0
# 15  29999.0     9-1-430     206143.0
# 16   2890.0     9-1-691     206143.0
# 17  33999.0     9-1-430     206181.0
# 18  33999.0     9-1-430     206198.0
# 19  36999.0     9-1-430     206235.0

# %%
precios1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472166 entries, 0 to 472165
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   precio       472153 non-null  float64
#  1   producto_id  472151 non-null  object
#  2   sucursal_id  472151 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 10.8+ MB

# %%
precios2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397734 entries, 0 to 397733
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   precio       397734 non-null  object
#  1   producto_id  397734 non-null  object
#  2   sucursal_id  397734 non-null  object
# dtypes: object(3)
# memory usage: 9.1+ MB

# %%
precios3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478909 entries, 0 to 478908
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   precio       477173 non-null  float64
#  1   sucursal_id  478909 non-null  object
#  2   producto_id  465390 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 11.0+ MB

# %%
#Se juntan las 3 tablas de precios
precio=pd.concat([precios1,precios2,precios3])

# %%
precio.tail(100)
# Out:
#          precio      producto_id sucursal_id
# 478809   1799.0  9002490203306.0      49-1-2
# 478810   1799.0  9002490203306.0      50-1-2
# 478811   3200.0  9002490203306.0     9-1-903
# 478812   3290.0  9002490203306.0       9-2-4
# 478813   3290.0  9002490203306.0     9-3-138
# ...         ...              ...         ...
# 478904  13999.0  9569753142128.0      25-1-1
# 478905   3499.0  9795403001143.0      25-1-1
# 478906   3125.0  9990385651922.0       5-1-3
# 478907   3125.0  9990385651939.0       5-1-3
# 478908   1989.0  9990385651946.0       5-1-3
#
# [100 rows x 3 columns]

# %%
#Automatizar
#Para automatizar se importa el nuevo conjunto de datos de precios
precios_cualquiera=pd.read_csv("/Users/Shared/CVS_Files/1-week-individual-project/precios_semana_20200518.txt",sep="|")
precios_cualquiera.head(20)

# %%
#Automatizar

precio_produc=precios_cualquiera['producto_id'].str.split('-', expand=True)
precio_produc.head()

# %%
#Se resuelve caso en el que producto_id no pueda ser int por separadores.
producto_product_final=precio_produc.apply(lambda row: row[0] if row[2] == None else row[2], axis=1)
precios_cualquiera["producto_id_key"]=producto_product_final

# %%
#Automatizar
#Se concatena la nueva tabla
precio=pd.concat([precio,precios_cualquiera])

# %%
#Automatizar
#Usamos sql para que sucursal_id conserve su tipo Varchar para mantener el foreing key
r_set=my_conn.execute("ALTER TABLE Precios_Semanas MODIFY COLUMN sucursal_id varchar(250);");

# %%
#Se termina automatizacion con un = precio.to_sql(con=my_conn,name='Precios_Semanas',if_exists='replace',index=False)

# %%
r_set=my_conn.execute("SET FOREIGN_KEY_CHECKS=0;");

# %%
#Se genero el foreing key
r_set=my_conn.execute("ALTER TABLE Precios_Semanas ADD FOREIGN KEY (sucursal_id) REFERENCES Sucursal(id);");
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py:206, in BaseCursor.execute(self, query, args)
# ...

# %%
#Se sube a el database los datos de precio actualizados
precio.to_sql(con=my_conn,name='Precios_Semanas',if_exists='replace',index=False)
# Out:
# 1348809

# %%
#Se lee el archivo parque que contiene la table de productos
producto=pd.read_parquet("/Users/Shared/CVS_Files/1-week-individual-project/producto.parquet",)

# %%
producto.tail(50)
# Out:
#                       id               marca  \
# 71988  9-3-0000000991247           SIN MARCA
# 71989  9-3-0000000991254           SIN MARCA
# 71990  9-3-0000000991278           SIN MARCA
# 71991  9-3-0000000991285           SIN MARCA
# 71992  9-3-0000000991292           SIN MARCA
# 71993  9-3-0000000991308           SIN MARCA
# 71994  9-3-0000000991339           SIN MARCA
# 71995  9-3-0000000991346           SIN MARCA
# 71996  9-3-0000000991353           SIN MARCA
# 71997  9-3-0000000991384           SIN MARCA
# 71998  9-3-0000000991391           SIN MARCA
# 71999  9-3-0000000991414           SIN MARCA
# 72000  9-3-0000000991421           SIN MARCA
# 72001  9-3-0000000991445           SIN MARCA
# 72002  9-3-0000000991452           SIN MARCA
# 72003  9-3-0000000991469           SIN MARCA
# 72004  9-3-0000000991483           SIN MARCA
# 72005  9-3-0000000992138           SIN MARCA
# 72006  9-3-0000000992251           SIN MARCA
# 72007  9-3-0000000992398           SIN MARCA
# ...

# %%
producto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72038 entries, 0 to 72037
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            72038 non-null  object
#  1   marca         72036 non-null  object
#  2   nombre        72036 non-null  object
#  3   presentacion  72036 non-null  object
#  4   categoria1    4 non-null      object
#  5   categoria2    4 non-null      object
#  6   categoria3    4 non-null      object
# dtypes: object(7)
# memory usage: 3.8+ MB

# %%
#producto=producto.replace('-','', inplace = True)

# %%
#Para usar integers por cuestiones de optimizacion en los id se sacan los separadores con el mismo metodo que en la tabla de precios
producto12=producto['id'].str.split('-', expand=True)
producto12.tail(50)
# Out:
#                    0     1              2
# 71988              9     3  0000000991247
# 71989              9     3  0000000991254
# 71990              9     3  0000000991278
# 71991              9     3  0000000991285
# 71992              9     3  0000000991292
# 71993              9     3  0000000991308
# 71994              9     3  0000000991339
# 71995              9     3  0000000991346
# 71996              9     3  0000000991353
# 71997              9     3  0000000991384
# 71998              9     3  0000000991391
# 71999              9     3  0000000991414
# 72000              9     3  0000000991421
# 72001              9     3  0000000991445
# 72002              9     3  0000000991452
# 72003              9     3  0000000991469
# 72004              9     3  0000000991483
# 72005              9     3  0000000992138
# 72006              9     3  0000000992251
# 72007              9     3  0000000992398
# 72008              9     3  0000000992725
# ...

# %%
producto13=producto12.apply(lambda row: row[0] if row[2] == None else row[0]+row[1]+row[2], axis=1)

# %%
producto13
# Out:
# 0        0000000001663
# 1        0000000002288
# 2        0000000205870
# 3        0000000205894
# 4        0000000205955
#              ...
# 72033    9569753142128
# 72034    9795403001143
# 72035    9990385651922
# 72036    9990385651939
# 72037    9990385651946
# Length: 72038, dtype: object

# %%
#producto12=producto12.apply(lambda row: row[0] if row[2] == None else row[2], axis=1)

# %%
producto["IdProducto"]=producto13

# %%
producto.tail(50)
# Out:
#                       id               marca  \
# 71988  9-3-0000000991247           SIN MARCA
# 71989  9-3-0000000991254           SIN MARCA
# 71990  9-3-0000000991278           SIN MARCA
# 71991  9-3-0000000991285           SIN MARCA
# 71992  9-3-0000000991292           SIN MARCA
# 71993  9-3-0000000991308           SIN MARCA
# 71994  9-3-0000000991339           SIN MARCA
# 71995  9-3-0000000991346           SIN MARCA
# 71996  9-3-0000000991353           SIN MARCA
# 71997  9-3-0000000991384           SIN MARCA
# 71998  9-3-0000000991391           SIN MARCA
# 71999  9-3-0000000991414           SIN MARCA
# 72000  9-3-0000000991421           SIN MARCA
# 72001  9-3-0000000991445           SIN MARCA
# 72002  9-3-0000000991452           SIN MARCA
# 72003  9-3-0000000991469           SIN MARCA
# 72004  9-3-0000000991483           SIN MARCA
# 72005  9-3-0000000992138           SIN MARCA
# 72006  9-3-0000000992251           SIN MARCA
# 72007  9-3-0000000992398           SIN MARCA
# ...

# %%
del producto["id"]

# %%
producto.rename(columns={'IdProducto': 'IdProducto', 'marca': 'Marca','nombre': 'Producto','presentacion': 'Unidad_de_Presentacion','categoria1': 'c1','categoria2': 'c2','categoria3': 'c3'}, inplace=True)

# %%
producto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72038 entries, 0 to 72037
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Marca                   72036 non-null  object
#  1   Producto                72036 non-null  object
#  2   Unidad_de_Presentacion  72036 non-null  object
#  3   c1                      4 non-null      object
#  4   c2                      4 non-null      object
#  5   c3                      4 non-null      object
#  6   IdProducto              72038 non-null  object
# dtypes: object(7)
# memory usage: 3.8+ MB

# %%
producto = producto[producto.c1.notna()]
print(producto)
# Out:
#           IdProducto    Marca                                     Producto  \
# 14903  7501001165260  PANTENE  Acondicionador Liso y Sedoso Pantene 400 Ml
# 53619  7798024299045     None                                         None
# 55798  7798061190213     None                                         None
# 65297  7798183771123    GRIDO                Helado en Pote Tentacion 1 Lt
#
#       Unidad_de_Presentacion                             c1               c2  \
# 14903               400.0 ml  Perfumería y Cuidado Personal  Cuidado Capilar
# 53619                   None                        Almacén          Aceites
# 55798                   None                        Almacén          Aceites
# 65297                 1.0 lt           Alimentos Congelados          Helados
#
#                      c3
# 14903  Acondicionadores
# 53619           Aerosol
# 55798             Oliva
# 65297           Helados

# %%
#Se utiliza un encoding utf8mb4 en el engine
my_conn=create_engine("mysql+mysqldb://root:"miclave"@localhost/Workshop_1?charset=utf8mb4")

# %%
#Pasa el valor a la base de datos
producto.to_sql(con=my_conn,name='Producto',if_exists='replace',index=False)
# Out:
# 72038
